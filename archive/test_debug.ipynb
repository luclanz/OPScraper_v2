# %%
from logging import raiseExceptions
from PIL import Image, ImageOps
import os
import requests
from bs4 import BeautifulSoup
import statistics

link = "https://onepiecechapters.com/chapters/5662/one-piece-chapter-1077"
chapter = 1077
tot_pages = 17

widthtol = (6, 10, 14, 18, 25, 50, 100)
npages = 0

#get the soup from the url
def getdata(url):
	r = requests.get(url)
	return r.text

htmldata = getdata(link)	
soup = BeautifulSoup(htmldata, 'html.parser')

#save all the relevant images
i = 1
for item in soup.find_all('img'):
    try:
        image = requests.get(soup.find_all('img')[i]['src'])
    except IndexError:
        break
    file = open('{0}.png'.format(i), "wb")
    file.write(image.content)
    file.close()
    i += 1

#get the data
data = []
for i in os.listdir():
   if i.endswith('.png'):
      im = Image.open(i, 'r').convert('P')
      data.append(tuple((im.size, len(Image.Image.getcolors(im)), i)))
      im.close()

# %%
#start engine ------------------------

#filter 1 - based on y dimensions
y_ = [data[j][0][1] for j in range(len(data))]
y_ = statistics.mode(y_)

data_filtered = filter(lambda y: y[0][1] > (y_ * 0.85) and y[0][1] < (y_ * 1.3), data)
data = list(data_filtered)

# %%
#filter 2 - based on number of colours
data = sorted(data, key = lambda x: x[1], reverse=False)

# %%
for i in range(17)[8:]:

    data_filtered = data[0:i]
    #print(f'try firts: {i} pages')

    x_width = [data_filtered[j][0][0] for j in range(len(data_filtered))]
    names = [data_filtered[j][2] for j in range(len(data_filtered))]
    xavg = sum(x_width) / (tot_pages-1)

# %%
print(data[0:8])
# Out:
# [((1100, 1600), 16, '14.png'), ((1100, 1596), 16, '15.png'), ((1100, 1609), 16, '12.png'), ((1100, 1606), 16, '13.png'), ((1100, 1600), 16, '11.png'), ((1100, 1634), 34, '16.png'), ((1100, 1612), 34, '6.png'), ((1100, 1608), 35, '8.png')]

# %%
for i in range(18)[8:]:

    data_filtered = data[0:i]
    print(f'try firts: {i} pages')

    x_width = [data_filtered[j][0][0] for j in range(len(data_filtered))]
    names = [data_filtered[j][2] for j in range(len(data_filtered))]
    xavg = sum(x_width) / tot_pages

    #loop for counting the pages
    for z in range(len(widthtol)):
        print(f'    try widthtol: {widthtol[z]}')
        npages = 0

        pages = []

        for j in range(len(x_width)):
            if (x_width[j] < (xavg + widthtol[z])) and (x_width[j] > (xavg - widthtol[z])):
                npages +=1
                print(npages)
                pages.append(tuple((1, data_filtered[j][2])))
                print('single', data_filtered[j][2])
                if npages == tot_pages:
                    break
                
            elif (x_width[j] < (xavg + 3*widthtol[z])*2) and (x_width[j] > (xavg - 3*widthtol[z])*2):
                npages += 2
                pages.append(tuple((2, data_filtered[j][2])))
                #print('double', new_data[j][2])
                if npages == tot_pages:
                    break
            else:
                print(f'        ERROR width page not within parameters, !({(xavg - 3*widthtol[z])*2:.0f} < {x_width[j]} < {(xavg + 3*widthtol[z])*2:.0f}): index {j}')
                break

        if npages == tot_pages:
            print(f'Found all {tot_pages} pages!')
            break

    if npages == tot_pages:
        break

if npages != tot_pages:
    raise Exception('Engine Failed')

#End Engine -------------------------------
# Out:
# try firts: 8 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(999 < 1100 < 1071): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(975 < 1100 < 1095): index 0
#     try widthtol: 14
#     try widthtol: 18
#     try widthtol: 25
#     try widthtol: 50
#     try widthtol: 100
# try firts: 9 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1129 < 1100 < 1201): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1105 < 1100 < 1225): index 0
#     try widthtol: 14
#     try widthtol: 18
#     try widthtol: 25
#     try widthtol: 50
#     try widthtol: 100
# try firts: 10 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1258 < 1100 < 1330): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1234 < 1100 < 1354): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1210 < 1100 < 1378): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1186 < 1100 < 1402): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1144 < 1100 < 1444): index 0
#     try widthtol: 50
#     try widthtol: 100
# try firts: 11 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1388 < 1100 < 1460): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1364 < 1100 < 1484): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1340 < 1100 < 1508): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1316 < 1100 < 1532): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1274 < 1100 < 1574): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1124 < 1100 < 1724): index 0
#     try widthtol: 100
# try firts: 12 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1517 < 1100 < 1589): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1493 < 1100 < 1613): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1469 < 1100 < 1637): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1445 < 1100 < 1661): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1403 < 1100 < 1703): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1253 < 1100 < 1853): index 0
#     try widthtol: 100
# try firts: 13 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1646 < 1100 < 1718): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1622 < 1100 < 1742): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1598 < 1100 < 1766): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1574 < 1100 < 1790): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1532 < 1100 < 1832): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1382 < 1100 < 1982): index 0
#     try widthtol: 100
# try firts: 14 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1776 < 1100 < 1848): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1752 < 1100 < 1872): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1728 < 1100 < 1896): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1704 < 1100 < 1920): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1662 < 1100 < 1962): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1512 < 1100 < 2112): index 0
#     try widthtol: 100
#         ERROR width page not within parameters, !(1212 < 1100 < 2412): index 0
# try firts: 15 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(1905 < 1100 < 1977): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(1881 < 1100 < 2001): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1857 < 1100 < 2025): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1833 < 1100 < 2049): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1791 < 1100 < 2091): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1641 < 1100 < 2241): index 0
#     try widthtol: 100
#         ERROR width page not within parameters, !(1341 < 1100 < 2541): index 0
# try firts: 16 pages
#     try widthtol: 6
#         ERROR width page not within parameters, !(2035 < 1100 < 2107): index 0
#     try widthtol: 10
#         ERROR width page not within parameters, !(2011 < 1100 < 2131): index 0
#     try widthtol: 14
#         ERROR width page not within parameters, !(1987 < 1100 < 2155): index 0
#     try widthtol: 18
#         ERROR width page not within parameters, !(1963 < 1100 < 2179): index 0
#     try widthtol: 25
#         ERROR width page not within parameters, !(1921 < 1100 < 2221): index 0
#     try widthtol: 50
#         ERROR width page not within parameters, !(1771 < 1100 < 2371): index 0
#     try widthtol: 100
# 1
# single 14.png
# 2
# single 15.png
# 3
# single 12.png
# 4
# single 13.png
# 5
# single 11.png
# 6
# single 16.png
# 7
# single 6.png
# 8
# single 8.png
# 9
# single 10.png
# 10
# single 9.png
# 11
# single 17.png
# 12
# single 18.png
# 13
# single 4.png
# 14
# single 5.png
# 15
# single 7.png
# 16
# single 3.png
# try firts: 17 pages
#     try widthtol: 6
# 1
# single 14.png
# 2
# single 15.png
# 3
# single 12.png
# 4
# single 13.png
# 5
# single 11.png
# 6
# single 16.png
# 7
# single 6.png
# 8
# single 8.png
# 9
# single 10.png
# 10
# single 9.png
# 11
# single 17.png
# 12
# single 18.png
# 13
# single 4.png
# 14
# single 5.png
# 15
# single 7.png
# 16
# single 3.png
# 17
# single 1.png
# Found all 17 pages!

# %%
#sort images (remove the '.png' at the end and sort as integers)
pages_sorted = sorted(pages, key = lambda tup: int(tup[1][:-4]))

#remove junk
for i in os.listdir():
    if i.endswith('.png') and i not in names:
        os.remove(i)

#merge func
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, min(im1.height, im2.height)))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

#rename images
i = 0
for item in pages_sorted:
    os.rename(item[1], f'{i}.png')
    if item[0] == 2:
        i += 2
    else:
        i += 1

#merge
for i in map(lambda x: 2*x + 1, range(8)):
    if f'{i+1}.png' not in os.listdir():
        continue
    else:
        imDX = Image.open(f'{i}.png')
        imSX = Image.open(f'{i+1}.png')
        get_concat_h(imSX, imDX).save(f'{i}.png')
        os.remove(f'{i+1}.png')

#pdf
image_list = []

for item in sorted(list(filter(lambda x: x.endswith('.png'), os.listdir())), key = lambda str: int(str[:-4])):
    if item == '0.png':
        imgg_ = Image.open(item)
        img_ = ImageOps.expand(imgg_, border=25, fill='white')
        imgg_ = img_.convert('RGB')
        #imgg_.save(item)
        continue
    img = Image.open(item)
    img_ = ImageOps.expand(img, border=25, fill='white')
    img_ = img_.convert('RGB')
    image_list.append(img_)
    #img_.save(item)

imgg_.save(f'{chapter}.pdf', save_all=True, append_images=image_list)

#remove junk
for item in os.listdir():
    if item.endswith('png'):
        os.remove(item)
